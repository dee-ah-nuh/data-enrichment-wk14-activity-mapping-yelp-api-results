# %% [markdown]
# # Part 1 - Extracting and Saving Data from Yelp API

# %% [markdown]
# ## Obective

# %% [markdown]
# - For this CodeAlong, we will be working with the Yelp API.
# - You will use the the Yelp API to search your home town for a cuisine type of your choice.
# - Next class, we will then use Plotly Express to create a map with the Mapbox API to visualize the results.

# %% [markdown]
# ## Tools You Will Use
# - Part 1:
#     - Yelp API:
#         - Getting Started:
#             - https://www.yelp.com/developers/documentation/v3/get_started
#
#     - `YelpAPI` python package
#         -  "YelpAPI": https://github.com/gfairchild/yelpapi
# - Part 2:
#
#     - Plotly Express: https://plotly.com/python/getting-started/
#         - With Mapbox API: https://www.mapbox.com/
#         - `px.scatter_mapbox` [Documentation](https://plotly.com/python/scattermapbox/):

# %% [markdown]
# ### Applying Code From
# - Efficient API Calls Lesson Link: https://login.codingdojo.com/m/376/12529/88078

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## 1. Registering for Required APIs

# %% [markdown]
# - Yelp: https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# > Check the official API documentation to know what arguments we can search for: https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open("/Users/Beemo/.secret/yelp_api.json") as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
from yelpapi import YelpAPI
yelp = YelpAPI(login['api-key'], timeout_s=5.0)
yelp

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = "Chicago, IL, 60647"
term = 'American'

# %%
## Specify fodler for saving data
folder = "Data/"
os.makedirs(folder,exist_ok=True)
#exist_ok = true creates an exception'

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = folder+f"Chicago-American.json"

# %%
location.split(',')[0]
# Out:
# 'Chicago'

# %%
#JSON_FILE = FOLDER+f{LOCATION.split(',')[0]}

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
# ## Check if JSON_FILE exists
# if os.path.isfile(JSON_FILE) ==False:
# ## If it does not exist: 
#     print("The file does not exist...bitch")
#     ## CREATE ANY NEEDED FOLDERS
#     # Get the Folder Name only
#     with open(JSON_FILE, 'w') as f:
#         json.dump(results['businesses'], f)
# else:
#     print("File exists...")
# ## If JSON_FILE included a folder:
# # create the folder  
# ## INFORM USER AND SAVE EMPTY LIST 
# ## save the first page of results        
# ## If it exists, inform user

# %% [markdown]
# ### Load JSON FIle and account for previous results

# %%
## Load previous results and use len of results for offset

## set offset based on previous results

# %% [markdown]
# ### Make the first API call to get the first page of data

# %% [markdown]
# - We will use this first result to check:
#     - how many total results there are?
#     - Where is the actual data we want to save?
#     - how many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call
results =yelp.search_query(term=term, location=location)
results
# Out:
# {'businesses': [{'id': 'okaqMJEoHfHblpKz9Q-CMA',
#    'alias': 'the-perch-chicago',
#    'name': 'The Perch',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6S7CbMwTmvjlbNSNJFW5Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-perch-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 330,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.90348, 'longitude': -87.676221},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1932 W Division',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1932 W Division', 'Chicago, IL 60622']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2498.2816327016462},
#   {'id': 'gzhkdb6YoiFm5s3vriG1AA',
#    'alias': 'gretel-chicago',
#    'name': 'Gretel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2SniAq7oiVXiasIuEmGT5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gretel-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 126,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.917275, 'longitude': -87.698577},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2833 W Armitage Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2833 W Armitage Ave', 'Chicago, IL 60647']},
#    'phone': '+17737703427',
#    'display_phone': '(773) 770-3427',
#    'distance': 121.33906559468214},
#   {'id': 'zm6Peew9j8YtowzUu4sQfA',
#    'alias': 'the-whale-chicago-chicago',
#    'name': 'The Whale Chicago',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PTPZJySRMPPN0pX0oKcyFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-whale-chicago-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 761,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.92555, 'longitude': -87.70112},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2427 N Milwaukee Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2427 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17738252900',
#    'display_phone': '(773) 825-2900',
#    'distance': 825.9643594723926},
#   {'id': 'DZ4lM8OHFK9gAdLffFWlTA',
#    'alias': 'the-leavitt-street-inn-and-tavern-chicago',
#    'name': 'The Leavitt Street Inn & Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NTFPOvFaGLwuiKrcf7xfXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-leavitt-street-inn-and-tavern-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 38,
#    'categories': [{'alias': 'bedbreakfast', 'title': 'Bed & Breakfast'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.924083, 'longitude': -87.682524},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2345 N Leavitt St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2345 N Leavitt St', 'Chicago, IL 60647']},
#    'phone': '+17736619639',
#    'display_phone': '(773) 661-9639',
#    'distance': 1482.405209911274},
#   {'id': 'sWYRaPCYHrTxsZPLWmzkzQ',
#    'alias': 'scofflaw-chicago',
#    'name': 'Scofflaw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pQw6qJbEOPyaHnhKk9562Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scofflaw-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 789,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9173240661621,
#     'longitude': -87.7071762084961},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3201 W Armitage Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3201 W Armitage Ave', 'Chicago, IL 60647']},
#    'phone': '+17732529700',
#    'display_phone': '(773) 252-9700',
#    'distance': 710.1374483002805},
#   {'id': 'mBG17MKjI3TNwYew5dzdyQ',
#    'alias': 'the-moonlighter-chicago',
#    'name': 'The Moonlighter',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JuyM65kYGJ4Y5f4CFWmIdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-moonlighter-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 227,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.91766, 'longitude': -87.70738},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3204 W Armitage Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3204 W Armitage Ave', 'Chicago, IL 60647']},
#    'phone': '+17733608896',
#    'display_phone': '(773) 360-8896',
#    'distance': 723.3919383316713},
#   {'id': 'bQDXNksi5lQ4YRv0kGSzjQ',
#    'alias': 'the-welcome-back-lounge-chicago',
#    'name': 'The Welcome Back Lounge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TjCUcUaKkS9YHQY6RI0PRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-welcome-back-lounge-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 57,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.92549, 'longitude': -87.701022},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2423 N Milwaukee Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2423 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17738252800',
#    'display_phone': '(773) 825-2800',
#    'distance': 815.0557438002392},
#   {'id': '0qW7MJ0trxnoWzCHBiBgbQ',
#    'alias': 'union-chicago-4',
#    'name': 'Union',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qwcsBgMKkFde1UpO7JWbQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/union-chicago-4?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 29,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9218, 'longitude': -87.69769},
#    'transactions': [],
#    'location': {'address1': '2202 N California Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2202 N California Ave', 'Chicago, IL 60647']},
#    'phone': '+17736977788',
#    'display_phone': '(773) 697-7788',
#    'distance': 399.8253788311252},
#   {'id': 'm5_GCJP2W4zEJnyVgxa3eA',
#    'alias': 'longman-and-eagle-chicago',
#    'name': 'Longman & Eagle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nkFuSeLKVdj4EYFWZFahuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/longman-and-eagle-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 2500,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.930156679293, 'longitude': -87.707222394898},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2657 N Kedzie Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2657 N Kedzie Ave', 'Chicago, IL 60647']},
#    'phone': '+17732767110',
#    'display_phone': '(773) 276-7110',
#    'distance': 1488.7341199026712},
#   {'id': 'kiwMgtypE3TRrUkmTwA2Zw',
#    'alias': 'armitage-alehouse-chicago',
#    'name': 'Armitage Alehouse',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yc8YcCtJJBFXxyDQyhyDBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/armitage-alehouse-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 121,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.91838, 'longitude': -87.65359},
#    'transactions': [],
#    'location': {'address1': '1000 W Armitage Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1000 W Armitage Ave', 'Chicago, IL 60614']},
#    'phone': '+17732706402',
#    'display_phone': '(773) 270-6402',
#    'distance': 3732.191330509913},
#   {'id': 'wfkj7DK8YzhdwhhFc2OntA',
#    'alias': 'giant-chicago-2',
#    'name': 'Giant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mkHyg5oqhQn1_rFXBynjvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giant-chicago-2?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 568,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9171, 'longitude': -87.70746},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '3209 W Armitage Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3209 W Armitage Ave', 'Chicago, IL 60647']},
#    'phone': '+17732520997',
#    'display_phone': '(773) 252-0997',
#    'distance': 745.4407232950657},
#   {'id': 'VPJk-SEWSWS_nGoQvM-COw',
#    'alias': 'penumbra-chicago',
#    'name': 'Penumbra',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2KoXY4qwg2vdy_dKmblDwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/penumbra-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 722,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.92445, 'longitude': -87.710933},
#    'transactions': ['restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3309 W Fullerton Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3309 W Fullerton Ave', 'Chicago, IL 60647']},
#    'phone': '+17737722343',
#    'display_phone': '(773) 772-2343',
#    'distance': 1217.1173361949689},
#   {'id': 'bwJ7IcLgQ228nkDCd4KO1A',
#    'alias': 'second-generation-chicago',
#    'name': 'Second Generation',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V-1GgCEnGocG3BLzyUYH5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/second-generation-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 2,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.92796, 'longitude': -87.70473},
#    'transactions': [],
#    'location': {'address1': '3057 W Logan Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3057 W Logan Blvd', 'Chicago, IL 60647']},
#    'phone': '+17739047620',
#    'display_phone': '(773) 904-7620',
#    'distance': 1177.8377552138738},
#   {'id': '80Hc97dvAL50tupxzswfRA',
#    'alias': 'tricycle-chicago-chicago',
#    'name': 'Tricycle Chicago',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lIHyi-6epQt75x45qfI3AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tricycle-chicago-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 104,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.91241005285812,
#     'longitude': -87.67767874294091},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1700 N Damen Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1700 N Damen Ave', 'Chicago, IL 60647']},
#    'phone': '+17736979275',
#    'display_phone': '(773) 697-9275',
#    'distance': 1861.6138124745473},
#   {'id': 'c6s7LYHo8lGclLXcKoOwMg',
#    'alias': 'spilt-milk-chicago-5',
#    'name': 'Spilt Milk',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q6QR8L-fjLTcHbb5N_FJag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spilt-milk-chicago-5?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 119,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.92497795950096,
#     'longitude': -87.69722434306789},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2758 W Fullerton Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2758 W Fullerton Ave', 'Chicago, IL 60647']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 745.8368231334637},
#   {'id': 'p5aez3TntyNQBza56g4KBg',
#    'alias': 'the-walk-in-chicago-chicago',
#    'name': 'The Walk In Chicago',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RJgnlbpyn4Mj0WokiYKXTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-walk-in-chicago-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 74,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9308832, 'longitude': -87.7101341},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2727 N Milwaukee Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2727 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17736978726',
#    'display_phone': '(773) 697-8726',
#    'distance': 1669.3244102041588},
#   {'id': 'OKOfoisduqP24uK3WYvx7Q',
#    'alias': 'revolution-brewing-chicago',
#    'name': 'Revolution Brewing',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VeD50KfZRcoVP9VaP3-Dtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/revolution-brewing-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 2162,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.92353, 'longitude': -87.698153},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2323 N Milwaukee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2323 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17732272739',
#    'display_phone': '(773) 227-2739',
#    'distance': 576.4952908988226},
#   {'id': 'fJkO3cfnNXrLIoYYGBX7_g',
#    'alias': 'table-donkey-and-stick-chicago',
#    'name': 'Table, Donkey and Stick',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kSHOCZoLzNIZhVkwBI3t0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/table-donkey-and-stick-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 473,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.91775, 'longitude': -87.695965},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2728 W Armitage Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2728 W Armitage Ave', 'Chicago, IL 60647']},
#    'phone': '+17734868525',
#    'display_phone': '(773) 486-8525',
#    'distance': 236.90248196300067},
#   {'id': 'aW7sY8DcTKfBFaXIH5vQxQ',
#    'alias': 'lucys-chicago',
#    'name': "Lucy's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-baMKxaA1pi_lzqQkrpSgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucys-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 233,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.90055, 'longitude': -87.69642},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1043 N California Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1043 N California Ave', 'Chicago, IL 60622']},
#    'phone': '+13126758385',
#    'display_phone': '(312) 675-8385',
#    'distance': 1989.6160548742573},
#   {'id': 'Nk4H9CkU8B1VPAofaB2qcQ',
#    'alias': 'mables-table-chicago',
#    'name': "Mable's Table",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u-kd1YqxXLLyni5QLe7Z8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mables-table-chicago?adjust_creative=RrPFJ6lUMwZMYSl1xY3Y_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=RrPFJ6lUMwZMYSl1xY3Y_Q',
#    'review_count': 347,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.915987, 'longitude': -87.669824},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1655 W Cortland St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1655 W Cortland St', 'Chicago, IL 60622']},
#    'phone': '+17739047433',
#    'display_phone': '(773) 904-7433',
#    'distance': 2404.4110716364235}],
#  'total': 1800,
#  'region': {'center': {'longitude': -87.6987075805664,
#    'latitude': 41.91836189511959}}}

# %%
## How many results total?
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
results
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Where is the actual data we want to save?

# %%
buss = results['businesses']

# %%
pd.DataFrame(buss)
# Out:
#                         id                                      alias  \
# 0   okaqMJEoHfHblpKz9Q-CMA                          the-perch-chicago
# 1   gzhkdb6YoiFm5s3vriG1AA                             gretel-chicago
# 2   zm6Peew9j8YtowzUu4sQfA                  the-whale-chicago-chicago
# 3   DZ4lM8OHFK9gAdLffFWlTA  the-leavitt-street-inn-and-tavern-chicago
# 4   sWYRaPCYHrTxsZPLWmzkzQ                           scofflaw-chicago
# 5   mBG17MKjI3TNwYew5dzdyQ                    the-moonlighter-chicago
# 6   bQDXNksi5lQ4YRv0kGSzjQ            the-welcome-back-lounge-chicago
# 7   0qW7MJ0trxnoWzCHBiBgbQ                            union-chicago-4
# 8   m5_GCJP2W4zEJnyVgxa3eA                  longman-and-eagle-chicago
# 9   kiwMgtypE3TRrUkmTwA2Zw                  armitage-alehouse-chicago
# 10  wfkj7DK8YzhdwhhFc2OntA                            giant-chicago-2
# 11  VPJk-SEWSWS_nGoQvM-COw                           penumbra-chicago
# 12  bwJ7IcLgQ228nkDCd4KO1A                  second-generation-chicago
# 13  80Hc97dvAL50tupxzswfRA                   tricycle-chicago-chicago
# 14  c6s7LYHo8lGclLXcKoOwMg                       spilt-milk-chicago-5
# 15  p5aez3TntyNQBza56g4KBg                the-walk-in-chicago-chicago
# 16  OKOfoisduqP24uK3WYvx7Q                 revolution-brewing-chicago
# 17  fJkO3cfnNXrLIoYYGBX7_g             table-donkey-and-stick-chicago
# 18  aW7sY8DcTKfBFaXIH5vQxQ                              lucys-chicago
# 19  Nk4H9CkU8B1VPAofaB2qcQ                       mables-table-chicago
#
#                                name  \
# 0                         The Perch
# 1                            Gretel
# 2                 The Whale Chicago
# 3   The Leavitt Street Inn & Tavern
# 4                          Scofflaw
# 5                   The Moonlighter
# 6           The Welcome Back Lounge
# 7                             Union
# 8                   Longman & Eagle
# 9                 Armitage Alehouse
# 10                            Giant
# 11                         Penumbra
# 12                Second Generation
# 13                 Tricycle Chicago
# 14                       Spilt Milk
# 15              The Walk In Chicago
# 16               Revolution Brewing
# 17          Table, Donkey and Stick
# 18                           Lucy's
# 19                    Mable's Table
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/6S7CbM...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/2SniAq...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/PTPZJy...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/NTFPOv...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/pQw6qJ...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/JuyM65...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/TjCUcU...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/qwcsBg...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/nkFuSe...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/yc8YcC...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/mkHyg5...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/2KoXY4...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/V-1GgC...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/lIHyi-...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/q6QR8L...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/RJgnlb...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/VeD50K...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/kSHOCZ...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/-baMKx...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/u-kd1Y...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-perch-chicago?adj...           330
# 1   https://www.yelp.com/biz/gretel-chicago?adjust...           126
# 2   https://www.yelp.com/biz/the-whale-chicago-chi...           761
# 3   https://www.yelp.com/biz/the-leavitt-street-in...            38
# 4   https://www.yelp.com/biz/scofflaw-chicago?adju...           789
# 5   https://www.yelp.com/biz/the-moonlighter-chica...           227
# 6   https://www.yelp.com/biz/the-welcome-back-loun...            57
# 7   https://www.yelp.com/biz/union-chicago-4?adjus...            29
# 8   https://www.yelp.com/biz/longman-and-eagle-chi...          2500
# 9   https://www.yelp.com/biz/armitage-alehouse-chi...           121
# 10  https://www.yelp.com/biz/giant-chicago-2?adjus...           568
# 11  https://www.yelp.com/biz/penumbra-chicago?adju...           722
# 12  https://www.yelp.com/biz/second-generation-chi...             2
# 13  https://www.yelp.com/biz/tricycle-chicago-chic...           104
# 14  https://www.yelp.com/biz/spilt-milk-chicago-5?...           119
# 15  https://www.yelp.com/biz/the-walk-in-chicago-c...            74
# 16  https://www.yelp.com/biz/revolution-brewing-ch...          2162
# 17  https://www.yelp.com/biz/table-donkey-and-stic...           473
# 18  https://www.yelp.com/biz/lucys-chicago?adjust_...           233
# 19  https://www.yelp.com/biz/mables-table-chicago?...           347
#
#                                            categories  rating  \
# 0   [{'alias': 'breweries', 'title': 'Breweries'},...     4.5
# 1   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 2   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 3   [{'alias': 'bedbreakfast', 'title': 'Bed & Bre...     5.0
# 4   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 5   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 6   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 7   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 8   [{'alias': 'gastropubs', 'title': 'Gastropubs'...     4.0
# 9   [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.5
# 10  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 11  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     5.0
# 12  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 13  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 14  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 15  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.5
# 16  [{'alias': 'breweries', 'title': 'Breweries'},...     4.0
# 17  [{'alias': 'modern_european', 'title': 'Modern...     4.0
# 18  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 19  [{'alias': 'newamerican', 'title': 'American (...     4.5
#
#                                           coordinates  \
# 0     {'latitude': 41.90348, 'longitude': -87.676221}
# 1    {'latitude': 41.917275, 'longitude': -87.698577}
# 2      {'latitude': 41.92555, 'longitude': -87.70112}
# 3    {'latitude': 41.924083, 'longitude': -87.682524}
# 4   {'latitude': 41.9173240661621, 'longitude': -8...
# 5      {'latitude': 41.91766, 'longitude': -87.70738}
# 6     {'latitude': 41.92549, 'longitude': -87.701022}
# 7       {'latitude': 41.9218, 'longitude': -87.69769}
# 8   {'latitude': 41.930156679293, 'longitude': -87...
# 9      {'latitude': 41.91838, 'longitude': -87.65359}
# 10      {'latitude': 41.9171, 'longitude': -87.70746}
# 11    {'latitude': 41.92445, 'longitude': -87.710933}
# 12     {'latitude': 41.92796, 'longitude': -87.70473}
# 13  {'latitude': 41.91241005285812, 'longitude': -...
# 14  {'latitude': 41.92497795950096, 'longitude': -...
# 15  {'latitude': 41.9308832, 'longitude': -87.7101...
# 16    {'latitude': 41.92353, 'longitude': -87.698153}
# 17    {'latitude': 41.91775, 'longitude': -87.695965}
# 18     {'latitude': 41.90055, 'longitude': -87.69642}
# 19   {'latitude': 41.915987, 'longitude': -87.669824}
#
#                           transactions price  \
# 0                   [pickup, delivery]    $$
# 1                   [pickup, delivery]    $$
# 2                   [pickup, delivery]    $$
# 3                   [delivery, pickup]    $$
# 4                           [delivery]    $$
# 5                           [delivery]    $$
# 6                                   []    $$
# 7                                   []   NaN
# 8                   [pickup, delivery]    $$
# 9                                   []   NaN
# 10                          [delivery]   $$$
# 11  [restaurant_reservation, delivery]    $$
# 12                                  []   NaN
# 13                  [pickup, delivery]    $$
# 14                          [delivery]    $$
# 15                                  []    $$
# 16                  [pickup, delivery]    $$
# 17                  [pickup, delivery]    $$
# 18                  [pickup, delivery]    $$
# 19                  [pickup, delivery]    $$
#
#                                              location         phone  \
# 0   {'address1': '1932 W Division', 'address2': No...
# 1   {'address1': '2833 W Armitage Ave', 'address2'...  +17737703427
# 2   {'address1': '2427 N Milwaukee Ave', 'address2...  +17738252900
# 3   {'address1': '2345 N Leavitt St', 'address2': ...  +17736619639
# 4   {'address1': '3201 W Armitage Ave', 'address2'...  +17732529700
# 5   {'address1': '3204 W Armitage Ave', 'address2'...  +17733608896
# 6   {'address1': '2423 N Milwaukee Ave', 'address2...  +17738252800
# 7   {'address1': '2202 N California Ave', 'address...  +17736977788
# 8   {'address1': '2657 N Kedzie Ave', 'address2': ...  +17732767110
# 9   {'address1': '1000 W Armitage Ave', 'address2'...  +17732706402
# 10  {'address1': '3209 W Armitage Ave', 'address2'...  +17732520997
# 11  {'address1': '3309 W Fullerton Ave', 'address2...  +17737722343
# 12  {'address1': '3057 W Logan Blvd', 'address2': ...  +17739047620
# 13  {'address1': '1700 N Damen Ave', 'address2': '...  +17736979275
# 14  {'address1': '2758 W Fullerton Ave', 'address2...
# 15  {'address1': '2727 N Milwaukee Ave', 'address2...  +17736978726
# 16  {'address1': '2323 N Milwaukee Ave', 'address2...  +17732272739
# 17  {'address1': '2728 W Armitage Ave', 'address2'...  +17734868525
# 18  {'address1': '1043 N California Ave', 'address...  +13126758385
# 19  {'address1': '1655 W Cortland St', 'address2':...  +17739047433
#
#      display_phone     distance
# 0                   2498.281633
# 1   (773) 770-3427   121.339066
# 2   (773) 825-2900   825.964359
# 3   (773) 661-9639  1482.405210
# 4   (773) 252-9700   710.137448
# 5   (773) 360-8896   723.391938
# 6   (773) 825-2800   815.055744
# 7   (773) 697-7788   399.825379
# 8   (773) 276-7110  1488.734120
# 9   (773) 270-6402  3732.191331
# 10  (773) 252-0997   745.440723
# 11  (773) 772-2343  1217.117336
# 12  (773) 904-7620  1177.837755
# 13  (773) 697-9275  1861.613812
# 14                   745.836823
# 15  (773) 697-8726  1669.324410
# 16  (773) 227-2739   576.495291
# 17  (773) 486-8525   236.902482
# 18  (312) 675-8385  1989.616055
# 19  (773) 904-7433  2404.411072

# %%
## How many did we get the details for?
#results_per_page = None
#results_per_page

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
# Use math.ceil to round up for the total number of pages of results.
import math
n_pages = math.ceil(results['total']/results_per_page)
n_pages
# Out:
# 90

# %%
if os.path.isfile(JSON_FILE)==False:
    # file does not exist so print message and create empty file
    print(" The file does not exist. Creating empty file.")
    with open(JSON_FILE,'w') as f:
        json.dump(results['businesses'],f)
# if file exists
else:
    print("File already exists")
# Out:
# File already exists

# %%
JSON_FILE
# Out:
# 'Data/Chicago-American.json'

# %%
## The block of code we want to TRY to run
## Read in results in progress file and check the length
## use n_results as the OFFSET     
## append new results and save to fill
## What to do if we get an error/exception.
for i in tqdm_notebook( range(1,n_pages+1)):
    with open(JSON_FILE) as f:
        prev_results = json.load(f)
    n_results = len(prev_results)
    results = yelp.search_query(term=term, location=location, offset =5)
    prev_results.extend(results['businesses'])
    with open(JSON_FILE, 'w') as f:
        json.dump(prev_results,f)
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [23], in <cell line: 6>()
#       6 for i in tqdm_notebook( range(1,n_pages+1)):
#       7     with open(JSON_FILE) as f:
# ----> 8         prev_results = json.load(f)
#       9     n_results = len(prev_results)
#      10     results = yelp.search_query(term=term, location=location, offset =5)
#
# File ~\.conda\envs\dojo-env\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~\.conda\envs\dojo-env\lib\json\__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File ~\.conda\envs\dojo-env\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\.conda\envs\dojo-env\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
JSON_FILE

# %%
df.to_csv(csv_file,compression='gzip',index=False)

# %% [markdown]
# ## Bonus: compare filesize with os module's `os.path.getsize`

# %%
size_json = os.path.getsize(JSON_FILE)
print(f'JSON FILE: {size_json:,} Bytes')

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize()####)

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

    
print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')

# %% [markdown]
# ## Next Class: Processing the Results and Mapping
